# %%
#01/07/2026
import pandas as pd

data = {
    "Age": [25, 35, 45, 20, 50, 32, 40],
    "Salary": [30000, 45000, 85000, 22000, 95000, 54000, 62000],
    "Gender": ["Female", "Male", "Female", "Male", "Female", "Male", "Female"],
    "Purchased": [0, 0, 1, 0, 1, 1, 1]
}

df = pd.DataFrame(data)

s
print("1. First 5 Rows :")
print(df.head(5))
# Out:
# --- 1. First 5 Rows ---
#    Age  Salary  Gender  Purchased
# 0   25   30000  Female          0
# 1   35   45000    Male          0
# 2   45   85000  Female          1
# 3   20   22000    Male          0
# 4   50   95000  Female          1

# %%
# 1. Display first 5 rows
print(" 1. First 5 Rows:")
print(df.head(5))
# Out:
#  1. First 5 Rows:
#    Age  Salary  Gender  Purchased
# 0   25   30000  Female          0
# 1   35   45000    Male          0
# 2   45   85000  Female          1
# 3   20   22000    Male          0
# 4   50   95000  Female          1

# %%
# 2. Display dataset information
print(" 2. Dataset Information :")
df.info()
# Out:
#  2. Dataset Information :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        7 non-null      int64
#  1   Salary     7 non-null      int64
#  2   Gender     7 non-null      object
#  3   Purchased  7 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 356.0+ bytes

# %%
# 3. Display statistical summary
print(" 3. Statistical Summary :")
print(df.describe())
# Out:
#  3. Statistical Summary :
#              Age        Salary  Purchased
# count   7.000000      7.000000   7.000000
# mean   35.285714  56142.857143   0.571429
# std    10.672617  26940.852322   0.534522
# min    20.000000  22000.000000   0.000000
# 25%    28.500000  37500.000000   0.000000
# 50%    35.000000  54000.000000   1.000000
# 75%    42.500000  73500.000000   1.000000
# max    50.000000  95000.000000   1.000000

# %%
# 4. Encode Gender column using map()
print("4. Encoded Gender Column :")
gender_mapping = {"Male": 0, "Female": 1}
df["Gender"] = df["Gender"].map(gender_mapping)
print(df)
# Out:
# 4. Encoded Gender Column :
#    Age  Salary  Gender  Purchased
# 0   25   30000       1          0
# 1   35   45000       0          0
# 2   45   85000       1          1
# 3   20   22000       0          0
# 4   50   95000       1          1
# 5   32   54000       0          1
# 6   40   62000       1          1

# %%
# 5. Find correlation between Age and Salary
print(" 5. Correlation Matrix (Age & Salary):")
correlation = df[["Age", "Salary"]].corr()
print(correlation)
# Out:
#  5. Correlation Matrix (Age & Salary):
#              Age    Salary
# Age     1.000000  0.974227
# Salary  0.974227  1.000000

# %%
# 6. Select features and target columns
print("--- 6. Features (X) and Target (y) Selection:")
X = df[["Age", "Salary", "Gender"]]
y = df["Purchased"]

print("Features (X):")
print(X.head(2))
print("\nTarget (y):")
print(y.head(2))
# Out:
# --- 6. Features (X) and Target (y) Selection:
# Features (X):
#    Age  Salary  Gender
# 0   25   30000       1
# 1   35   45000       0
#
# Target (y):
# 0    0
# 1    0
# Name: Purchased, dtype: int64
