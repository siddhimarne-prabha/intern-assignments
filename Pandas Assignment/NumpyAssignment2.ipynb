# %%
#03/07/2026
import numpy as np
print(" Q1 :")
arr_q1 = np.array([10, 20, 30, 40, 50])
print("First element:", arr_q1[0])
# Out:
#  Q1 :
# First element: 10

# %%
print(" Q2:")
arr_q2 = np.array([5, 10, 15, 20, 25, 30])
print("Last element (negative indexing):", arr_q2[-1])
# Out:
#  Q2:
# Last element (negative indexing): 30

# %%
print(" Q 3 :")
arr_q3 = np.array([100, 200, 300, 400, 500])
print("Third element:", arr_q3[2])
# Out:
#  Q 3 :
# Third element: 300

# %%
matrix_2d = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])
print(matrix_2d)
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 80 90]]

# %%
print(" Q 4:")
print("Element 50:", matrix_2d[1, 1])
# Out:
#  Q 4:
# Element 50: 50

# %%
print("Q 5:")
print("Element 90:", matrix_2d[2, 2])
# Out:
# Q 5:
# Element 90: 90

# %%
matrix_3d = np.array([
    [[1, 2], [3, 4]],
    [[5, 6], [7, 8]]
])
print(matrix_3d)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
print("Q6:")
print("Element 6:", matrix_3d[1, 0, 1])
# Out:
# Q6:
# Element 6: 6

# %%
print(" Q 7:")
print("Element 3:", matrix_3d[0, 1, 0])
# Out:
#  Q 7:
# Element 3: 3

# %%
array= np.array([10, 20, 30, 40, 50, 60, 70, 80])
print(array)
# Out:
# [10 20 30 40 50 60 70 80]

# %%
print("Q8:")
print("First four elements:", array[:4])
# Out:
# Q8:
# First four elements: [10 20 30 40]

# %%
print("Q 9:")
print("Elements from 30 to 60:", array[2:6])
# Out:
# Q 9:
# Elements from 30 to 60: [30 40 50 60]

# %%
print("Q10:")
print("Elements from 50 to end:", array[4:])
# Out:
# Q10:
# Elements from 50 to end: [50 60 70 80]

# %%
print("Question 11 :")
print("Every second element:", array[::2])
# Out:
# Question 11 :
# Every second element: [10 30 50 70]

# %%
print("Question 12:")
print("Last three elements:", array[-3:])
# Out:
# Question 12:
# Last three elements: [60 70 80]

# %%
print("Question 13:")
print("First row:\n", matrix_2d[0])
# Out:
# Question 13:
# First row:
#  [10 20 30]

# %%
print(" Question 14:")
print("Last row:\n", matrix_2d[-1])
# Out:
#  Question 14:
# Last row:
#  [70 80 90]

# %%
print(" Question 15:")
print("Second column:\n", matrix_2d[:, 1])
# Out:
#  Question 15:
# Second column:
#  [20 50 80]

# %%
print("Question 16 :")
print("Third column:\n", matrix_2d[:, 2])
# Out:
# Question 16 :
# Third column:
#  [30 60 90]

# %%
print("Question 17:")
print("First two rows:\n", matrix_2d[:2])
# Out:
# Question 17:
# First two rows:
#  [[10 20 30]
#  [40 50 60]]

# %%
print("Question 18:")
print("First two columns:\n", matrix_2d[:, :2])
# Out:
# Question 18:
# First two columns:
#  [[10 20]
#  [40 50]
#  [70 80]]

# %%
print("Question 19:")
print("matrix:\n", matrix_2d[:2, :2])
# Out:
# Question 19:
# matrix:
#  [[10 20]
#  [40 50]]

# %%
print(" Question 20 :")
arr_q20 = np.array([10, 20, 30, 40, 50])
print("Array created:\n", arr_q20)
# Out:
#  Question 20 :
# Array created:
#  [10 20 30 40 50]
